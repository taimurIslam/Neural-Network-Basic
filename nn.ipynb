# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
data = [[3,   1.5, 1],
        [2,   1 ,  0],
        [4,   1.5, 1],
        [3,   1,   0],
        [3.5, .5,  1],
        [2,   .5,  0],
        [5.5,  1,  1],
        [1,   1,   0]]

# %%
test_data = [4.5, 1]

# %%
#network
w1 = np.random.randn()
w2 = np.random.randn()
b = np.random.randn()
print("w1 = "+str(w1)+"\n"+"w2 = "+str(w2)+"\n"+"b = "+str(b))
# Out:
# w1 = -0.3060573636091258
# w2 = -0.14510694224398607
# b = 0.6415769844608605

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))
def sigmoid_p(x):
    return sigmoid(x) *(1-sigmoid(x))

# %%
t = np.linspace(-5, 5, 1000)
s = sigmoid(t)
s_p = sigmoid_p(t)
plt.plot(t, s)
plt.plot(t, s_p)

# %%
plt.axis([0, 6, 0, 6])
plt.grid()
for i in range(len(data)):
    point = data[i]
    color ='r'
    if point[2] == 0:
        color = 'b'
    plt.scatter(point[0], point[1], c= color)

# %%
for i in range(1000):
    random_index = np.random.randint(len(data))
    point = data[random_index]
    z = w1 * point[0] + w2 * point[1] +b
    prediction = sigmoid(z)
    
    cost = np.square(prediction - point[2])
    
    
    #derivative calculation
    derivative_of_cost = 2 * (prediction - point[2])
    derivative_of_prediction = sigmoid_p(z)
    #derivative_of_w1 with respect to w1
    derivative_of_w1 = piint[0]
    #derivative_of_w1 with respect to w2
    derivative_of_w2 = point[1]
    #derivative_of_w1 with respect to b
    derivative_of_b = 1
# Out:
# [4, 1.5, 1]
# 0.476157141897
# [3.5, 0.5, 1]
# 0.388092690702
# [3.5, 0.5, 1]
# 0.388092690702
# [2, 1, 0]
# 0.221955002745
# [3, 1, 0]
# 0.156902765044
# [2, 0.5, 0]
# 0.239344880568
# [2, 1, 0]
# 0.221955002745
# [5.5, 1, 1]
# 0.587026279243
# [3, 1, 0]
# 0.156902765044
# [2, 1, 0]
# 0.221955002745
# [3.5, 0.5, 1]
# 0.388092690702
# [2, 1, 0]
# 0.221955002745
# [2, 0.5, 0]
# 0.239344880568
# [2, 0.5, 0]
# 0.239344880568
# [3.5, 0.5, 1]
# 0.388092690702
# [3, 1, 0]
# 0.156902765044
# [3, 1.5, 1]
# 0.385775657474
# [5.5, 1, 1]
# 0.587026279243
# [3.5, 0.5, 1]
# 0.388092690702
# [2, 0.5, 0]
# 0.239344880568
# [3, 1.5, 1]
# 0.385775657474
# [3, 1.5, 1]
# 0.385775657474
# [1, 1, 0]
# 0.299712298599
# [1, 1, 0]
# 0.299712298599
# [2, 0.5, 0]
# 0.239344880568
# [5.5, 1, 1]
# 0.587026279243
# [3, 1, 0]
# 0.156902765044
# [2, 0.5, 0]
# 0.239344880568
# [1, 1, 0]
# 0.299712298599
# [1, 1, 0]
# 0.299712298599
# [5.5, 1, 1]
# 0.587026279243
# [3, 1, 0]
# 0.156902765044
# [3, 1, 0]
# ...
